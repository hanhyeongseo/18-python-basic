# %%
# 위치 인수를 사용하는 함수를 만들고 호출하기
def print_numbers(a, b, c):
    print(a)
    print(b)
    print(c)

print_numbers(10, 20, 30)
# Out:
# 10
# 20
# 30

# %%
# 언패킹 사용하기 //395p// 
x = [10, 20, 30]
print_numbers(x) # => ([10, 20, 30])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # 언패킹 사용하기 //395p//
#       2 x = [10, 20, 30]
# ----> 3 print_numbers(x) # => ([10, 20, 30])
#
# TypeError: print_numbers() missing 2 required positional arguments: 'b' and 'c'

# %%
x = [10, 20, 30]
print_numbers(*x) # => ([10, 20, 30])
# Out:
# 10
# 20
# 30

# %%
# 가변인수 함수 만들기
# def 함수이름(*매개변수):
#     코드

def print_numbers(*args): #알규먼츠 약자
    for arg in args:
        print(arg)

# %%
print_numbers(10)
print("=============")
print_numbers(10, 20, 30, 40)
# Out:
# 10
# ...
# 10
# 20
# 30
# 40

# %%
def print_numbers(*args): #알규먼츠 약자
    # print(args)
    # print(type(args))
    for arg in args:
        print(arg)

print_numbers(10, 20, 30)
# Out:
# 10
# 20
# 30

# %%
print_numbers([1, 2, 3, 4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %%
print_numbers(*[1, 2, 3, 4, 5])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# 키워드 인수 사용하기
def personal_info(name, age, address):
    print("이름:", name)
    print("나이:", age)
    print("주소:", address)
personal_info(age=30, address="서울시 용산구", name="홍길동",)
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구

# %%
personal_info("홍길동", 30, "서울시 용산구")
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구

# %%
# 키워드 인수
# 함수(키워드=값)

personal_info(name="홍길동", age=30, address="서울시 용산구")
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구

# %%
personal_info(age=30, address="서울시 용산구", name="홍길동",)
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구

# %%
# 키워드 인수와 딕셔너리 언패킹 사용하기
# 함수(**딕셔너리)
def personal_info(name, age, address):
    print("이름:", name)
    print("나이:", age)
    print("주소:", address)

x={
    "name": "홍길동",
    "age": 30,
    "address":"서울시 용산구"
}

personal_info(**x)
# ㄴ == personal_info(name="홍길동", age=30, address="서울시 용산구")   // 언팩킹
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 용산구

# %%
# 키워드 인수를 사용하는 가변 인수 함수 만들기(여러개 인수 집어넣을수있다)

# def 함수이름(**매개변수): 
#     코드

def personal_info(**kwargs):    #**가 붙었기 때문에 함수에 들어오는 키워드 인수들을 딕셔너리로 묶어서 받습니다. == {"name": "홍길동"}인 딕셔너리 형태
    print(kwargs)
    print(type(kwargs))
    for kw, arg in kwargs.items():    #items가 키와 값을 둘다 가져온다.
        print(kw, ": ", arg, sep="")
        # ㄴ == print("name", ": ", "홍길동", sep="")
        
personal_info(name="홍길동")   # (name="홍길동")==키워드인수
# Out:
# {'name': '홍길동'}
# <class 'dict'>
# name: 홍길동

# %%
personal_info(name="홍길동", age=30, address="서울시 용산구")
# Out:
# {'name': '홍길동', 'age': 30, 'address': '서울시 용산구'}
# <class 'dict'>
# name: 홍길동
# age: 30
# address: 서울시 용산구

# %%
def personal_info(**kwargs):
    for kw, arg in kwargs.items():
        print(kw, ": ", arg, sep="")

x={
    "name": "홍길동",
    "age": 30,
    "address":"서울시 용산구",
    "hobby": ["축구", "농구", "게임"]
}

personal_info(**x)
# Out:
# name: 홍길동
# age: 30
# address: 서울시 용산구
# hobby: ['축구', '농구', '게임']

# %%
# 매개변수에 초깃값 지정하기
# def 함수이름(매개변수=값):
#     코드

def personal_info(name, age, address="비공개"):  # 디폴트 값 설정 가능
    print("이름:", name)
    print("나이:", age)
    print("주소:", address)

personal_info("홍길동", 30)
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 비공개

# %%
personal_info("홍길동", 30, "서울시 이촌동")
# Out:
# 이름: 홍길동
# 나이: 30
# 주소: 서울시 이촌동

# %%
# 초깃값이 지정된 매개변수의 위치
def personal_info(name, address="비공개", age):  # 디폴트 값 설정 가능
    print("이름:", name)
    print("나이:", age)
    print("주소:", address)
# Out:
#   Cell In[34], line 2
#     def personal_info(name, address="비공개", age):  # 디폴트 값 설정 가능
#                                            ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def personal_info(name, address="비공개", age=0):  # 디폴트 값 설정시 뒤쪽에 몰아서 디폴트 설정// 디폴트 했다가 안했다가 하면 에러뜸
    print("이름:", name)
    print("나이:", age)
    print("주소:", address)

personal_info("홍길동")
# Out:
# 이름: 홍길동
# 나이: 0
# 주소: 비공개

# %%
# 연습문제 30.6
korean, english, mathematics, science = 100,86, 81, 91

def get_max_score(*args):
    return max(args)

max_score = get_max_score(korean, english, mathematics, science)
print("높은 점수:", max_score)

max_score = get_max_score(english, science)
print("높은 점수:", max_score)
# Out:
# 높은 점수: 100
# 높은 점수: 91

# %%
# 심사문제 30.7  (76 82 89 84)
korean, english, mathematics, science = map(int,input().split())

def get_min_max_score(*scores):                 #튜플
    return min(scores), max(scores)

def get_average(**scores):                      #딕셔너리
    return sum(scores.values()) / len(scores)

min_score,max_score = get_min_max_score(korean, english, mathematics, science)
average_score = get_average(korean=korean, english=english, mathematics=mathematics, science=science)
print("낮은 점수: {0:.2f}, 높은 점수:{1:.2f}, 평균 점수:{2:.2f}".format(min_score, max_score, average_score))

min_score, max_score = get_min_max_score(english,science)
average_score = get_average(english=english, science=science)
print("낮은 점수: {0:.2f}, 높은 점수:{1:.2f}, 평균 점수:{2:.2f}".format(min_score, max_score, average_score))
# Out:
# 낮은 점수: 76.00, 높은 점수:89.00, 평균 점수:82.75
# 낮은 점수: 82.00, 높은 점수:84.00, 평균 점수:83.00

# %%
# 커피 가격
coffee_price = {
    "아메리카노": 3000,
    "카페라떼": 4000,
    "카푸치노": 4500,
    "바닐라라떼": 5000
}

# 매출과 비용을 저장
daily_sales = 0
daily_cost = 0
monthly_sales = 0
monthly_cost = 0


# 커피 주문 및 계산 함수
def order_coffee(coffee, quantity):
    global daily_sales, daily_cost
    global monthly_sales, monthly_cost

    price = coffee_price[coffee]
    sales = price * quantity

    # 커피 한 잔당 원가를 판매 가격의 40%로 설정
    cost = sales * 0.4

    daily_sales += sales
    daily_cost += cost

    monthly_sales += sales
    monthly_cost += cost

    print(coffee, quantity, "잔 주문")
    print("결제 금액:", sales, "원")


# 매출과 수익을 보여주는 함수
def show_sales():
    daily_profit = daily_sales - daily_cost
    monthly_profit = monthly_sales - monthly_cost

    print("\n===== 매출 현황 =====")
    print("일별 매출:", daily_sales, "원")
    print("일별 수익:", daily_profit, "원")
    print("월별 매출:", monthly_sales, "원")
    print("월별 수익:", monthly_profit, "원")


# 주문
order_coffee("아메리카노", 2)
order_coffee("카페라떼", 1)
order_coffee("바닐라라떼", 3)

# 매출 확인
show_sales()
# Out:
# 아메리카노 2 잔 주문
# 결제 금액: 6000 원
# 카페라떼 1 잔 주문
# 결제 금액: 4000 원
# 바닐라라떼 3 잔 주문
# 결제 금액: 15000 원
#
# ===== 매출 현황 =====
# 일별 매출: 25000 원
# 일별 수익: 15000.0 원
# 월별 매출: 25000 원
# 월별 수익: 15000.0 원
