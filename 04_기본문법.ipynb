# %%
#세미콜론
print("Hello Woerld")
# Out:
# Hello Woerld

# %%
#한줄 주석
#출력하라
print("hello world")
# Out:
# hello world

# %%
#블록 주석===컨트롤 슬래쉬
# print("hello world")
# print("hello world")
# print("hello world")

# %%
#들여쓰기
##소주제
a = 5
if a == 10:
    print("10입니다.")
      #print("들여쓰기 여백 안맞추면 안된다") $$$들여쓰기 정확히

# %%
#저장 필수 후 작업진행==실행안될수도
