# %%
# 변수만들기

x = 10  # 10 먼저 읽고 그게 X변수에 저장된다 , x는 그릇


## 1. 영문 문자와 숫자 사용
## 2. 대소문자 구분
## 3. 문자부터시작해야함
## 4. _(밑줄 문자)로 시작할 수 있음
## 5. 특수문자(+, -, *, $, /, @, % 등) 사용할 수 없음
## 6. 파이썬 키워드 (if, for, while, and, or) 사용할 수 없음

# %%
x = 10  #변수지정이자 튜플형식
print(x)
# Out:
# 10

# %%
print = 100
print
# Out:
# 100

# %%
print("hello world") ##키워드를 변수로 설정했기 때문에 오류 발생 ,,,위에서 print 변수로 사용===del print 적용해서 정상화
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print("hello world")
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
a=10
hello_world = "hi" #snake case
helloWorld = "hi" ###camel case
HelloWorld = "hi" ##pascal case

# %%
#변수의 자료형 알아내기
x=10
print(x)
type(x)
# Out:
# 10
# int

# %%
y = "hello world"
type(y)
# Out:
# str

# %%
#변수 여러개를 한번에 만들기 
x,y,z=10,20,30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
x, y, z= 10,20 ##변수 3개인데 2개만 넣으면 에러
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 x, y, z= 10,20
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
x = y = z = 10 ##z는 10의 주소를 가르키고있고, y는 z의 주소를 가리키고 있다.
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
x, y =10, 20
x,y = y,z         ###python만 가능###############

print(x)
print(y)
# Out:
# 20
# 10

# %%
# 변수로 계산하기
a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %%
#const a: int    ####다른언어는 변수를 만들기위해 예약어(const)를 만들고 타입(int)을 선언해야한다.

# %%
#산술 연산 후 할당 연산자 사용하기
a = 10
a + 20
print(a)

###데이터프레임할때 주의///판다스 할때 헷갈림 주의 ///재할당 안해주면 a값이 변하지않는다
# Out:
# 10

# %%
a = 10
a = a + 20
print(a)
# Out:
# 30

# %%
a = 10
a += 20      # a = a + 20 
print(a)
# Out:
# 30

# %%
#입력값을 변수에 저장하기
##input 함수 사용하기
input()
# Out:
# 'hello world'

# %%
##input 함수의 결과를 변수에 할당
a = input()

# %%
a
# Out:
# 'hello world'

# %%
x = input("문자열을 입력하세요") ##이건 입력하는 창에서 확인가능(==문자열을 입력하세요)
print(x)
# Out:
# 100

# %%
# 두 숫자의 합 구하기
a = input("첫 번째 숫자를 입력하세요: ")
b = input("두 번째 숫자를 입력하세요: ")
print(a + b)
# Out:
# 1020

# %%
print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'str'>

# %%
a = int(input("첫 번째 숫자를 입력하세요: "))
b = int(input("두 번째 숫자를 입력하세요: "))
print(a + b)
# Out:
# 30

# %%
# 입력 값을 변수 두 개에 저장하기
a = input("문자열 두 개를 입력하세요").split()
print(a)
print(b)
# Out:
# ['hello', 'world']
# 20

# %%
a, b = [10, 20] #list형태 타입///튜플 형태로 a,b =10, 20///a,b=(10,20) 전부 가능
print(a)
print(b)
# Out:
# 10
# 20

# %%
a.split() ###매서드 split은 매써드 함수형태로 사용===리스트형태의 데이터 타입이 나온다.
# Out:
# ['hello', 'python']

# %%
# 두 숫자의 합 구하기
#a, b = input("숫자 두 개를 입력하세요: ").split()  ##문자열이기때문에 .split()  가능
a,b = "10 20".split() #윗줄이랑 같은말

print(a+b)
# Out:
# 1020

# %%
a = int(a)
b = int(b)
print(a + b)
# Out:
# 30

# %%
# map을 사용하여 정수로 변환하기
a, b = map(int, ["10", "20"]) ##매핑@@@자주쓰게된다###$$$ map사용할때 int 사용법이 달라진다. 괄호없이 함수를 적는다.
print(a)
print(b)
print("=====")
print(type(a))
print(type(b))
# Out:
# 10
# 20
# =====
# <class 'int'>
# <class 'int'>

# %%
a, b = map(int, input("숫자 두 개를 입력하세요: ").split())
print(a +b)

#=발견시 오른쪽 부터 읽는다. split 읽고 int 보고 input읽는다. int 정수형태로 변환 후 a,b에 각각 대입한다.
# Out:
# 30

# %%
#입력받은 값을 콤마를 기준으로 분리하기
#"10,20".split()

"10,20".split(",") ## 콤마를 기준으로 나누어라===리스트형식으로 나옴
# Out:
# ['10', '20']

# %%
a, b = map(int, input("숫자 두 개를 입력하세요: ").split(","))
print(a +b)
# Out:
# 30

# %%
##연습문제 6.6    (-10 20 30)
a,b,c =map(int, input().split())
print(a+b+c)
# Out:
# 40

# %%
##심사문제 6.7
a,b,c = map(str, input().split())

print(a)
print(b)
print(c)

# a, b, c = input().split()
# print(a)
# print(b)
# print(c)
# Out:
# 50
# 100
# None

# %%
##심사문제 6.8 (입력값: 83 92 87 90)
a,b,c,d = map(int, input().split())
print(int((a+b+c+d)/4))
# Out:
# 88

# %%
##심사문제 6.8 (입력값: 32 53 22 95)
a,b,c,d = map(int, input().split())
print(int((a+b+c+d)/4))
# Out:
# 50

# %%
##심사문제 6.8 (입력값: 32 53 22 95)
# numbers = list(map(int, input().split()))
# print(int(sum(numbers) / len(numbers)))
# #범용적인 방식
# Out:
# 50
