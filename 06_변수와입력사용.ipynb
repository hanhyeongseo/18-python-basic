# %%
# 변수만들기

x = 10  # 10 먼저 읽고 그게 X변수에 저장된다 , x는 그릇


## 1. 영문 문자와 숫자 사용
## 2. 대소문자 구분
## 3. 문자부터시작해야함
## 4. _(밑줄 문자)로 시작할 수 있음
## 5. 특수문자(+, -, *, $, /, @, % 등) 사용할 수 없음
## 6. 파이썬 키워드 (if, for, while, and, or) 사용할 수 없음

# %%
x = 10
print(x)
# Out:
# 10

# %%
print = 100
print
# Out:
# 100

# %%
print("hello world") ##키워드를 변수로 설정했기 때문에 오류 발생 ,,,위에서 print 변수로 사용===del print 적용해서 정상화
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print("hello world")
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
x=10
hello_world = "hi" #snake case
helloWorld = "hi" ###camel case
helloWorld = "hi" ##pascal case

# %%
#변수의 자료형 알아내기
x=10
print(X)
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 #변수의 자료형 알아내기
#       2 x=10
# ----> 3 print(X)
#       4 type(x)
#
# NameError: name 'X' is not defined

# %%
y = "hello world"
type(y)
# Out:
# str

# %%
#변수 여러개를 한번에 만들기 
x,y,z=10,20,30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
x, y, z= 10,20 ##변수 3개인데 2개만 넣으면 에러
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 x, y, z= 10,20
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
x = y = z = 10 ##z는 10의 주소를 가르키고있고, y는 z의 주소를 가리키고 있다.
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
x, y =10, 20
x,y = y,z         ###python만 가능###############

print(x)
print(y)
# Out:
# 20
# 10

# %%
# 변수로 계산하기
a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %%
#const a: int    ####다른언어는 변수를 만들기위해 예약어(const)를 만들고 타입(int)을 선언해야한다.

# %%
#산술 연산 후 할당 연산자 사용하기
a = 10
a + 20
print(a)

###데이터프레임할때 주의///판다스 할때 헷갈림 주의 ///재할당 안해주면 a값이 변하지않는다
# Out:
# 10

# %%
a = 10
a = a + 20
print(a)
# Out:
# 30

# %%
a = 10
a += 20      # a = a + 20 
print(a)
# Out:
# 30
