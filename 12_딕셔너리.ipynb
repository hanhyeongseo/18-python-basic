# %%
# # 딕셔너리 만들기
# 딕셔너리 = {
#     키1:값1,
#     키2:값2
# }

#이런형식을 제이슨 형태라고 한다.
#csv=엑셀형태

lux = {
    'health': 490, 
    'mana': 334, 
    'melee': 550,
    "armor": 18.72
}
lux
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 키이름이 중복이 되면?
lux = {
    "health": 490, 
    "health": 800,
    "mana": 334, 
    "melee": 550,
    "armor": 18.72
}
lux["health"]
# Out:
# 800

# %%
lux ##중복되면 뒤에꺼 들고옴
# Out:
# {'health': 800, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 딕셔너리의 키의 자료형
##키에는 리스트와 딕셔너리는 사용할 수 없음 ==== 변경되는 값은 사용불가

x = {
    100: "hundred",
    False: 0,
    3.5: [3.5, 3.5]
}
x
# Out:
# {100: 'hundred', False: 0, 3.5: [3.5, 3.5]}

# %%
x = {
    [10, 20],
    30
}
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x = {
#       2     [10, 20],
#       3     30
#       4 }
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
# 빈 딕셔너리 만들기
딕셔너리 = {}
딕셔너리 = dict()
# int(), str(), float(), list(), tuple(), bool()

x={}
y= dict()

print(x)
print(y)
print(type(x))
print(type(y))
# Out:
# {}
# {}
# <class 'dict'>
# <class 'dict'>

# %%
# dict로 딕셔너리 만들기

lux1 = dict(
    health=490, mana=334, melee=550, armor=18.72
)
lux1

#주황색은 파라미터로 우리가 임의로 만든 거(health mana melee armor)
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
iter1 = ["health", "mana", "melee", "armor"]
iter2 = [490, 334, 550, 18.72]
# list(zip(iter1, iter2))
dict(zip(iter1, iter2))###############***********zip , map***********************^*&%*$%^$&#&$^*#$#*$*#$^#&*$^&*
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux3 = dict(
    [("health",490), ("mana", 334), ('melee', 550), ("armor", 18.72)]
)

lux3
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux4 = dict(
    {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}
)
lux4
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
#딕셔너리의 키에 접근하고 값 할당하기
lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}
lux["health"]
# Out:
# 490

# %%
lux["armor"]
# Out:
# 18.72

# %%
# 딕셔너리의 키에 값 할당하기
lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}
lux["health"] = 2037
lux["mana"] = 1184

print(lux)
# Out:
# {'health': 2037, 'mana': 1184, 'melee': 550, 'armor': 18.72}

# %%
lux["mana_regen"] = 3.28  #없는값 추가
lux
# Out:
# {'health': 2037,
#  'mana': 1184,
#  'melee': 550,
#  'armor': 18.72,
#  'mana_regen': 3.28}

# %%
lux["attack-speed"]

#없는값 찾기
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 lux["attack-speed"]
#       2
#       3 #없는값 찾기
#
# KeyError: 'attack-speed'

# %%
# 딕셔너리에 키가 있는지 확인하기

lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}
"health" in lux
# Out:
# True

# %%
# 딕셔너리의 키 개수 구하기
lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}
len(lux)
# Out:
# 4

# %%
# 연습문제 12.4
camille = {
    'health': 575.6,
    'health_regen': 1.7,
    'mana': 338.8,
    'mana_regen': 1.63,
    'melee': 125,
    'attack_damage': 60,
    'attack_speed': 0.625,
    'armor': 26,
    'magic_resistance': 32.1,
    'movement_speed': 340
}

print(camille['health'])
print(camille['movement_speed'])
# Out:
# 575.6
# 340

# %%
# 심사문제 12.5^^^^^^^^^^ (health health_regen mana mana_regen)  (575.6 1.7 338.8 1.63)^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^$
iter1 = input().split()
iter2 = list(map(float, input().split()))   #input(내가 넣어준 값)을 split(여백)을 기준으로 분리한다/ map(float, 분리된 각각의 값을 실수형으로 변환하고 list형태로 변환
dict(zip(iter1, iter2))
# Out:
# {'health': 575.6, 'health_regen': 1.7, 'mana': 338.8, 'mana_regen': 1.63}

# %%
print(iter1)
print(iter2)

list(zip(iter1, iter2))
# Out:
# ['health', 'health_regen', 'mana', 'mana_regen']
# [575.6, 1.7, 338.8, 1.63]
# [('health', 575.6),
#  ('health_regen', 1.7),
#  ('mana', 338.8),
#  ('mana_regen', 1.63)]
