# %%
# # if 조건문 사용하기

# if 조건식:
#     코드

x = 10
if x== 10:
    print("10입니다.")
# Out:
# 10입니다.

# %%
# if 조건문을 사용할때 주의할점

if x = 10:
# Out:
#   Cell In[2], line 3
#     if x =10:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# if조건문에서 코드를 생략하기
x = 10
if x == 10:
    pass #보통 임시로 if문 덜만들면 쓰는듯 또는 통상적으로 사용

# %%
# if 조건문과 들여쓰기

x = 10

if x == 10:
    print("x에 들어있는 숫자는")
    print("10입니다.")
# Out:
# x에 들어있는 숫자는
# 10입니다.

# %%
x = 10

if x == 10:
    print("x에 들어있는 숫자는")
print("10입니다.")                  #shift Tab 하면 내여쓰기로 전환

#마지막줄은 if문 아님
# Out:
# x에 들어있는 숫자는
# 10입니다.

# %%
# 중첩 if조건문 사용하기 (elif 안쓰고 중첩 if)
x = 15
if x >= 10:
    print("10이상입니다.")

    if x == 15:
        print("15입니다.")

    if x == 20:
        print("20입니다.")

        #중복 if 는 모든 if를 거치는건가??????????????앞에서 ok뜨면 멈추는게아니라?
# Out:
# 10이상입니다.
# 15입니다.

# %%
# 사용자가 입력한 값에 if 조건문 사용하기
x = int(input())

if x ==10:
    print("10입니다.")

if x == 20:
    print("20입니다.")
# Out:
# 10입니다.

# %%
# 연습문제 13.6
x = 5
if x != 10:
    print('ok')
# Out:
# ok

# %%
# 심사문제 13.7
number = int(input())
coupon = input()

sale = coupon[-4:]

# if type(sale) != int:
sale = int(sale)

number - sale

#+++++++++++++++++++++++
# if "Cash3000" in dis:
#     dis = 3000
#     print(fee - dis)

# else "cash5000"
# Out:
# 24000
