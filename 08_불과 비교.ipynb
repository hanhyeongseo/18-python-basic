# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
# 비교연산자
3 > 1
# Out:
# True

# %%
# 숫자가 같은지 다른지 비교
print(10 == 10) #10과 10이 같은지 비교
print(10 != 5)  #10과 5가 다른지 비교
# Out:
# True
# True

# %%
print("Python" == "Python")
print("Python" == "python") #대문자와 소문자는 구분한다.
# Out:
# True
# False

# %%
#부등호 사용하기
print(10 > 20)
print(10 < 20)
print(10 >= 20)
print(10 <= 20)
# Out:
# False
# True
# False
# True

# %%
print(1 == 1.0)
# print(1 is 1.0) # ==False #is는 이제 잘안씀, 같은주소를 가리키고있는지 확인하는 함수
print(id(1))
print(id(1.0))
# === : 타입까지 같다는 의미
# Out:
# True
# 140707516441720
# 2060056095664

# %%
# 논리연산자 사용하기

print(True and True and True)
print(True and False and True)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or  False)
print(False or  True)
print(False  or False)

# 알트 클릭 클릭 클릭 후 같이 편집가능
# Out:
# True
# True
# True
# False

# %%
not True and False or not False

False and False or True # 위에 줄 해석 시

False or True # 최종 해석

#and or 연산자는 마지막에 해석한다.
# Out:
# True

# %%
# 논리연산자와 비교 연산자를 함께 사용하기

print(10 == 10 and 10 != 5)
print(10 > 5 or 10 < 3)
print(not (10 > 5)) # 0을 제외한 모든 숫자는 True이다. 따라서 not 10 == False 이다.
print(not 1 is 1.0) 

#and or 연산자는 마지막에 해석한다. 비교연산자 우선
#판다스 라이브러리 할때는 계산 멋대로 하기때문에 괄호를 필수로 하자!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# True
# True
# False
# True
# <>:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDT76\AppData\Local\Temp\ipykernel_4244\337734126.py:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
#연습문제 8.4
korean = 92
english = 47
mathematics = 86
science = 81

print(korean >= 50 and english >= 50 and mathematics >= 50 and science >= 50)
# Out:
# False

# %%
#연습문제 8.5   (90 81 86 80)
a,b,c,d = map(int, input().split())
print(a >= 90 and b > 80 and c > 85 and d >= 80)
# Out:
# True

# %%
#연습문제 8.5   (90 80 85 80)
a,b,c,d = map(int, input().split())
print(a >= 90 and b > 80 and c > 85 and d >= 80)
# Out:
# False

# %%
1 == True
# Out:
# True

# %%
#0을 제외한 모든 숫자는 True이다. 따라서 not 10 == False 이다./ 0 == False
## "0이 아닌 숫자는 True다" →  bool()이나 if 같은 참/거짓 판단에서 그렇습니다.**********************
