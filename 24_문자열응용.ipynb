# %%
# 문자열 바꾸기
"Hello World".replace("World","Python")
# Out:
# 'Hello Python'

# %%
[].append(0)

# %%
s = "Hello World"
s.replace("World","Python")
s
# Out:
# 'Hello World'

# %%
# 문자 바꾸기
table = str.maketrans("aeiou", "12345")
"apple".translate(table)
# Out:
# '1ppl2'

# %%
# 문자열 분리하기
"appple pear grape pineapple orange".split()  #기본값 공백 기준으로 나눔
# Out:
# ['appple', 'pear', 'grape', 'pineapple', 'orange']

# %%
"appple pear grape pineapple orange".replace(" ", ", ")
# Out:
# 'appple, pear, grape, pineapple, orange'

# %%
'appple,pear,grape,pineapple,orange'.split(",")
# Out:
# ['appple', 'pear', 'grape', 'pineapple', 'orange']

# %%
# 구분자 문자열과 문자열 리스트 연결하기
" ".join(['appple', 'pear', 'grape', 'pineapple', 'orange'])
# Out:
# 'appple pear grape pineapple orange'

# %%
"-".join(['appple', 'pear', 'grape', 'pineapple', 'orange'])
# Out:
# 'appple-pear-grape-pineapple-orange'

# %%
# 소문자를 대문자로 바꾸기
"python".upper()
# Out:
# 'PYTHON'

# %%
'PYTHON'.lower()
# Out:
# 'python'

# %%
#왼쪽끝 공백삭제
"    Python    ".rstrip()
# Out:
# '    Python'

# %%
#오른끝 공백
"    Python    ".lstrip()
# Out:
# 'Python    '

# %%
#양끝쪽 공백
"    Python    ".strip()
# Out:
# 'Python'

# %%
# 특정문자 삭제하기
",. python. .,".strip(",.")
# Out:
# ' python. '

# %%
", python. ".strip()
# Out:
# ', python.'

# %%
",. python. .,".strip(",.").strip().strip(".")
# Out:
# 'python'

# %%
# 문자열을 왼쪽 정렬
"python".ljust(10)
# Out:
# 'python    '

# %%
"python".rjust(10)
# Out:
# '    python'

# %%
#문자열을 가운데 정렬하기
"python".center(11)
# Out:
# '   python  '

# %%
# 문자열 왼쪽에 0 채우기
"35".zfill(4)
# Out:
# '0035'

# %%
"3.5".zfill(6)
# Out:
# '0003.5'

# %%
"hello".zfill(10)
# Out:
# '00000hello'

# %%
# 문자열 위치 찾기 #인덱스 출력
"apple pineapple".find("pl")
# Out:
# 2

# %%
"apple pineapple".rfind("plX")
# Out:
# -1

# %%
"apple pineapple".index("pl")
# Out:
# 2

# %%
"apple pineapple".rindex("plx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 "apple pineapple".rindex("plx")
#
# ValueError: substring not found

# %%
# 문자열 개수 세기
"apple pineapple".count("pl")
# Out:
# 2

# %%
"apple pineapple".count("p")
# Out:
# 5

# %%
# 문자열 서식 지정자와 포매팅 사용하기
# %s % "문자열"

"I am %s" % "james"
# Out:
# 'I am james'

# %%
name = "maria"
"I am %s" % name
# Out:
# 'I am maria'

# %%
# 서식지정자로 숫자 넣기
# "%d" % 숫자

"I am %d" % 20

b = 10
"I am %d" %b
# Out:
# 'I am 10'

# %%
# 서식지정자로 소수점 표현하기
# "%f" % 숫자(실수)

"%f" % 2.3
# Out:
# '2.300000'

# %%
# "%.자리수f" % 숫자
print("%.2f" % 2.3)
print("%5.2f" % 2.3)
# Out:
# 2.30
#  2.30

# %%
# 서식 지정자로 문자열 정렬하기
# % 길이 s 
"%10s" % "python"
# Out:
# '    python'

# %%
# 왼쪽 정렬하기 
"%-10s" % "python"
# Out:
# 'python    '

# %%
# 서식 지정자로 문자열 안에 값 여러개 넣기
# "%d %s" %(숫자, 문자열)

"Today is %d %s" %(3, "April")
# Out:
# 'Today is 3 April'

# %%
# format 매서드 사용하기 (매서드는.붙여쓰기.format)
"Hello, {0}".format("world")
# Out:
# 'Hello, world'

# %%
# format 매서드로 값을 여러개 넣기
"Hello {0} {2} {1}".format("python", "Script", 3.6)
# Out:
# 'Hello python 3.6 Script'

# %%
# format 매서드로 같은 값을 여러개 넣기
"{0} {0} {1} {1}".format("Python", "Script")
# Out:
# 'Python Python Script Script'

# %%
# format 매서드에 인덱스 생략하기 
"Hello {} {} {}".format("python", "Script", 3.6)
# Out:
# 'Hello python Script 3.6'

# %%
# format매서드에서 인덱스 대신 이름 지정하기
print("Hello {language} {version}".format(language="Python",version=3.6))
# Out:
# Hello Python 3.6

# %%
# 문자열 포매팅에 변수를 그대로 사용하기
language = "Python"
version = 3.6

print(f"Hello {language} {version}")
# Out:
# Hello Python 3.6

# %%
# format 매서드로 문자열 정렬하기
# "{인덱스:<10}".format("python")
print("{0:<10}".format("python"))
print("{0:>10}".format("python"))
print("{:>10}".format("python"))
# Out:
# python
#     python
#     python

# %%
# 숫자 개수 맞추기
# "%0개수d" % 숫자
# "{인덱스:0개수d}".format(숫자)
print("%03d" % 1)
print("{0}".format(35))
print("{:03d}".format(35))
# Out:
# 001
# 35
# 035

# %%
print("%.2f" % 3.6)
print("%8.2f" % 3.6)
print("%08.2f" % 3.6)
###############
print("{}".format(150.37))
print("{:.2f}".format(150.37))
print("{:.1f}".format(150.37))
# Out:
# 3.60
#     3.60
# 00003.60
# 150.37
# 150.37
# 150.4
#   150.37
# 00150.37

# %%
print("{:8.2f}".format(150.37))
print("{:08.2f}".format(150.37))
# Out:
#   150.37
# 00150.37

# %%
# 채우기와 정렬을 조합해서 사용하기
print("{:0<15}".format(15))
print("{:<15}".format(15))
# Out:
# 150000000000000
# 15

# %%
number = 3.6
print(f"{number:.2f}")
print(f"{number:10.2f}")
print(f"{number:010.2f}")
# Out:
# 3.60
#       3.60
# 0000003.60

# %%
#1000단위 구분 + 소수점뒤 2째자리
number = 30000
print(f"{number:,.2f}")
# Out:
# 30,000.00

# %%
# 연습문제 24.4
path = 'C:\\Users\\dojang\\AppData\\Local\\programs\\Python\\Python36-32\\python.exe'

x=path.split('\\')
filename =x[-1]

#x = path.split("\\")
#x.reverse(
#filename = x[0]


##filename = path[path.rfind('\\')+1]

# path.split("\")

print(filename)
# Out:
#   Cell In[109], line 14
#     path.split("\")
#                ^
# SyntaxError: unterminated string literal (detected at line 14); perhaps you escaped the end quote?

# %%
# 심사문제 24.5
"이재명 대통령은 18일 호르무즈 해협 파병 문제와 관련해 “전쟁에 관여하거나 개입하는 파병은 없다”고 단언했다. 이 대통령은 이날 청와대 기자회견에서 “그런 형태의 군 자산 파병은 없다는 원칙을 지켜왔고, 앞으로도 원칙에 변함이 없다”며 이같이 말했다. 다만 이 대통령은 “다만 우리로서는 다른 국가들이 하는 것처럼 자국의 상선과 원유수송로, 국민들의 생명과 안전을 보호하기 위한 최소한의 활동은 해야 한다는 점도 분명하다”고 했다. 그러면서 “아시는 것처럼 이미 청해부대가 파견돼 해적 등의 국민 안전 위협에 대해 대응하고 있다. 이를 좀 강화하는 부분에 대해 우리가 검토하고 고심하는 건 사실”이라고 덧붙였다. 이 대통령은 “이게 마치 전쟁에 관여하거나 지원하는 파병이 아니냐, 전투 병력을 보내는 것 아니냐는 걱정들이 있으신 것 같다. 다시 한번 말씀드리면 전쟁 파병은 없다”고 강조했다. 이 대통령은 우리 상선의 홍해 진입에 대해서는 “우리 상선들이 홍해에 진입하지 않다 보니 전쟁 초기 원유 수급에 상당한 차질이 있더라”며 “낮은 단계의 위험을 이유로 원유 수송을 포기하면 경제에 너무 큰 타격이 있으니 홍해 진입을 검토해보라고 지시했다. 이는 제가 책임질 일”이라고 말했다.".count("전쟁")
# Out:
# 4

# %%
# 심사문제 24.6 (51900;83000;158000;367500;250000;59200;128500;1304000)
imsi = list(map(int, input().split(";")))
for i in sorted(imsi):
    print(f"{i:9,}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 2
#       1 # 심사문제 24.6 (51900;83000;158000;367500;250000;59200;128500;1304000)
# ----> 2 imsi = list(map(int, input().split(";")))
#       3 imsi.sort(reverse=True)
#       4 print(imsi)
#
# ValueError: invalid literal for int() with base 10: '# 심사문제 24.6 (51900'

# %%
lis = map(int,input().split(";"))

# %%
lis = list(lis)
lis
# Out:
# [51900, 83000, 158000, 367500, 250000, 59200, 128500, 1304000]

# %%
lis = sorted(lis, reverse=True)
lis
# Out:
# [1304000, 367500, 250000, 158000, 128500, 83000, 59200, 51900]

# %%
for i in lis:
    print(f"{i:9,}")
# Out:
# 1,304,000
#   367,500
#   250,000
#   158,000
#   128,500
#    83,000
#    59,200
#    51,900

# %%
# 심사문제 24.6 (51900;83000;158000;367500;250000;59200;128500;1304000)---모범답안
lis = map(int, input().split(";"))
for i in sorted(lis, reverse=True):
    print(f"{i:9,}")
# Out:
# 1,304,000
#   367,500
#   250,000
#   158,000
#   128,500
#    83,000
#    59,200
#    51,900

# %%
a = [1, 3, 9, 7, 5]
print(a.sort(reverse=True))
# Out:
# None

# %%
lis = list(map(int, input().split(";")))
lis.sort(reverse=True)
for i in lis:
    print(f"{i:9,}")
# Out:
# 1,304,000
#   367,500
#   250,000
#   158,000
#   128,500
#    83,000
#    59,200
#    51,900
