# %%
#사칙연산
1+1
# Out:
# 2

# %%
"1" + "1"
# Out:
# '11'

# %%
1-2
# Out:
# -1

# %%
5/2
# Out:
# 2.5

# %%
4/2
# Out:
# 2.0

# %%
##소수점 이하를 버리는 연산자 // =========몫 구하기
print(6//2)
4//2  ##print 미기입시 가장 아래꺼만 알려줌
# Out:
# 3
# 2

# %%
#나머지를 구하는 연산자 %

(5 % 2)
(7 % 3)

#홀짝 구분할때, 5의배수 같은거 구할때
# Out:
# 1

# %%
#거듭제곱을 구하는 **연산자
2**10
10**10
# Out:
# 10000000000

# %%
#값을 정수로 만들기 @@@@@@@@@@@@@@@시험 중요@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
int(3.3)
int(5/2)###소수점 아래 내림으로 버린다.
int("1")####문자형 타입을 정수형 타입으로 다시 변경
# Out:
# 1

# %%
#객체의 자료형 알아내기

type(10)  #int==정수
type("1") #str==string==문자
# Out:
# str

# %%
#실수계산하기
3.5 + 2.1
# Out:
# 5.6

# %%
#실수와 정수를 함께 계산하면
4.2 + 5
# Out:
# 9.2

# %%
#값을 실수로 만들기
print(float(5))
print(float(1 + 2)) ##시프트 알트 아래방향키
print(float("5.3")) #문자열을 실수 형태로
# Out:
# 5.0
# 3.0
# 5.3

# %%
# 괄호 사용하기
35 + 1 * 2 #인간이하는 사칙연산 순서로계산
# Out:
# 37

# %%
(35 + 1) * 2  #판다스에서 ?? 할때 헷갈림 주의
# Out:
# 72

# %%
#연습문제 5.5
print(int(0.2467 * 12 + 4.159))
# Out:
# 7

# %%
#연습문제 5.6
print(102 * 0.6 +225)
# Out:
# 286.2
